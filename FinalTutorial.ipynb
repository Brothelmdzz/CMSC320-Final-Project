# %% [markdown]
# <a href="https://colab.research.google.com/github/Brothelmdzz/CMSC320-Final-Project/blob/main/FinalTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the final project for CMSC320

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn
from statsmodels.formula.api import ols
from sklearn.feature_selection import f_regression
from sklearn import linear_model

data = pd.read_excel('HateCrimeStat.xls')
data
# Out:
#                                                  Bias  2015  ...  2018  2019
# 0                               Single-Bias Incidents  5818  ...  7036  7103
# 1                            Race/Ethnicity/Ancestry:  3310  ...  4047  3963
# 2                                          Anti-White   613  ...   762   666
# 3                      Anti-Black or African American  1745  ...  1943  1930
# 4               Anti-American Indian or Alaska Native   131  ...   194   119
# 5                                          Anti-Asian   111  ...   148   158
# 6      Anti-Native Hawaiian or Other Pacific Islander     4  ...    20    21
# 7                          Anti-Multiple Races, Group   113  ...   137   134
# 8                                           Anti-Arab    37  ...    82    95
# 9                             Anti-Hispanic or Latino   299  ...   485   527
# 10                 Anti-Other Race/Ethnicity/Ancestry   257  ...   276   313
# ...

# %%
# We will first calculate the percentage of racial bias incidents throughout the five years
data['Total'] = data[2015] + data[2016] + data[2017] + data[2018] + data[2019]

for x in range(2015, 2020):
  data['percentage of ' + str(x)] = data[x] / data['Total']
data.head()
# Out:
#                                     Bias  ...  percentage of 2019
# 0                  Single-Bias Incidents  ...            0.214424
# 1               Race/Ethnicity/Ancestry:  ...            0.209240
# 2                             Anti-White  ...            0.190177
# 3         Anti-Black or African American  ...            0.205977
# 4  Anti-American Indian or Alaska Native  ...            0.140165
#
# [5 rows x 12 columns]
